# %% [markdown]
# <a href="https://colab.research.google.com/github/ollihansen90/zeugs/blob/main/FourierSeries_KreisePlotten.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.youtube.com/watch?v=r6sGWTCMz2k

# %%
import numpy as np
import matplotlib.pyplot as plt

base = np.linspace(-1,1, num=1000)
f = lambda a, freq, x: a*np.array([np.sin(freq*2*np.pi*x), np.cos(freq*2*np.pi*x)])

y = f(1,1,base)
for i in range(-10,10):
    if i:
        y += f(1/i,i,base)
plt.figure()
plt.plot(y[0], y[1])
plt.show()
